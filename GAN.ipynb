# %%
import requests
from bs4 import BeautifulSoup
import os
import traceback

def download(url, filename):
    if os.path.exists(filename):
        print('file exists!')
        return
    try:
        r = requests.get(url, stream=True, timeout=60)
        r.raise_for_status()
        with open(filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                if chunk:  # filter out keep-alive new chunks
                    f.write(chunk)
                    f.flush()
        return filename
    except KeyboardInterrupt:
        if os.path.exists(filename):
            os.remove(filename)
        raise KeyboardInterrupt
    except Exception:
        traceback.print_exc()
        if os.path.exists(filename):
            os.remove(filename)

# %%
if os.path.exists('imgs') is False:
    os.makedirs('imgs')

start = 1
end = 2
for i in range(start, end + 1):
    url = 'http://konachan.net/post?page=%d&tags=' % i
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    for img in soup.find_all('img', class_="preview"):
        target_url = 'http:' + img['src']
        filename = os.path.join('imgs', target_url.split('/')[-1])
        download(target_url, filename)
    print('%d / %d' % (i, end))
# Out:
# 1 / 2
# 2 / 2

# %%
## detection of animation face

import cv2
import sys
import os.path
from glob import glob

def detect(filename, cascade_file="lbpcascade_animeface.xml"):
    if not os.path.isfile(cascade_file):
        raise RuntimeError("%s: not found" % cascade_file)
    try:
        cascade = cv2.CascadeClassifier(cascade_file)
        image = cv2.imread(filename)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        gray = cv2.equalizeHist(gray)
    
        faces = cascade.detectMultiScale(gray,
                                         # detector options
                                         scaleFactor=1.1,
                                         minNeighbors=5,
                                         minSize=(48, 48))
        for i, (x, y, w, h) in enumerate(faces):
            face = image[y: y + h, x:x + w, :]
            face = cv2.resize(face, (96, 96))
            save_filename = '%s-%d.jpg' % (os.path.basename(filename).split('.')[0], i)
            cv2.imwrite("faces/" + save_filename, face)
    except:
        pass


if os.path.exists('faces') is False:
    os.makedirs('faces')
file_list = glob('imgs/*.jpg')
for filename in file_list:
    detect(filename)

# %%
## jiandan girl
header = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}

if os.path.exists('imgs') is False:
    os.makedirs('imgs')

start = 201
end = 200
for i in range(start, end + 1):
    url = 'http://jandan.net/ooxx/page-' + str(i)
    request = urllib.request.Request(url,headers=headers)
    response = urllib.request.urlopen(request)
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')
    for img in soup.find_all('img'):
        if 'border' not in str(img) and 'gif' not in str(img):    
            target_url = 'http:' + img['src']
            random.shuffle(items)
            filename = os.path.join('imgs', ''.join(str(e) for e in items)+target_url.split('/')[-1])
            download(target_url, filename)

# %%
import requests
from bs4 import BeautifulSoup
import os
import traceback
import urllib.request
import random

# %%
url1 = 'http:' + href['href']
request1 = urllib.request.Request(url1,headers=headers)
response1 = urllib.request.urlopen(request1)
html1 = response1.read()
soup1 = BeautifulSoup(html1, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-57-d37dfd416b6e> in <module>()
#       1 url1 = 'http:' + href['href']
#       2 request1 = urllib.request.Request(url1,headers=headers)
# ----> 3 response1 = urllib.request.urlopen(request1)
#       4 html1 = response1.read()
#       5 soup1 = BeautifulSoup(html1, 'html.parser')
#
# /Users/zihaozhang/anaconda/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /Users/zihaozhang/anaconda/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     462         for processor in self.process_request.get(protocol, []):
#     463             meth = getattr(processor, meth_name)
# ...

# %%
soup.find_all('a', href = True)[8]
# Out:
# <a class="lady-avatar" href="//mm.taobao.com/631300490.htm" target="_blank"> <img alt="" height="60" src="//gtd.alicdn.com/sns_logo/i8/TB1JRHEQpXXXXXwXVXXSutbFXXX.jpg_60x60.jpg" width="60"/>
# </a>

# %%
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}

for i in range(2):
    url = 'http://mm.taobao.com/json/request_top_list.htm'+ "?page=" + str(i)
    request = urllib.request.Request(url,headers=headers)
    response = urllib.request.urlopen(request)
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')

    for href in soup.find_all('a', href = True):
        try:
            url1 = 'http:' + href['href']
            request1 = urllib.request.Request(url1,headers=headers)
            response1 = urllib.request.urlopen(request1)
            html1 = response1.read()
            soup1 = BeautifulSoup(html1, 'html.parser')
            for img in soup1.find_all('img')[0:4]:
                if 'border' not in str(img) and 'gif' not in str(img):    
                    target_url = 'http:' + img['src']
                    randomnumber = [5,6,7,8,'g','x','y','i']
                    random.shuffle(randomnumber)
                    filename = os.path.join('imgs', ''.join(str(e) for e in randomnumber)+target_url.split('/')[-1])
                    download(target_url, filename)
        except:
            continue
# Out:
# Traceback (most recent call last):
#   File "/Users/zihaozhang/anaconda/lib/python3.5/site-packages/requests/models.py", line 374, in prepare_url
#     scheme, auth, host, port, path, query, fragment = parse_url(url)
#   File "/Users/zihaozhang/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/util/url.py", line 199, in parse_url
#     raise LocationParseError(url)
# requests.packages.urllib3.exceptions.LocationParseError: Failed to parse: http:
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-1-c2d93e388f69>", line 11, in download
#     r = requests.get(url, stream=True, timeout=60)
#   File "/Users/zihaozhang/anaconda/lib/python3.5/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/Users/zihaozhang/anaconda/lib/python3.5/site-packages/requests/api.py", line 58, in request
# ...

# %%
## jiandan girl
header = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}

if os.path.exists('imgs') is False:
    os.makedirs('imgs')

start = 1
end = 200
for i in range(start, end + 1):
    url = 'http://mm.taobao.com/json/request_top_list.htm'+ "?page=" + str(i)
    request = urllib.request.Request(url,headers=headers)
    response = urllib.request.urlopen(request)
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')
    for img in soup.find_all('img'):
        if 'border' not in str(img) and 'gif' not in str(img):    
            target_url = 'http:' + img['src']
            random.shuffle(items)
            filename = os.path.join('imgs', ''.join(str(e) for e in items)+target_url.split('/')[-1])
            download(target_url, filename)

# %%
def urlrequest(url):
    request = urllib.request.Request(url,headers=headers)
    response = urllib.request.urlopen(request)
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')
    pattern = re.compile('{"pin_id":(\d*?),.*?"key":"(.*?)",.*?"like_count":(\d*?),.*?"repin_count":(\d*?),.*?}',re.S)
    items = re.findall(pattern,soup.text)
    return items

def downloaditems(items):
    url_image = "http://hbimg.b0.upaiyun.com/"
    for item in items:
        max_pin_id = item[0]
        x_key = item[1]
        x_like_count = int(item[2])
        x_repin_count = int(item[3])
        if (x_repin_count >1 and x_like_count > 1) or x_repin_count >3 or x_like_count > 3:
            target_url = url_image+x_key
            randomnumber = [6,7,8,9,0,'l','k']
            random.shuffle(randomnumber)
            filename = os.path.join('imgs', ''.join(str(e) for e in randomnumber)+str(max_pin_id)+".jpg")
            download(target_url, filename)
    return max_pin_id

# %%
urlNext = "http://huaban.com/favorite/beauty/?iqkxaeyv&limit=20&wfl=1&max="
url = urlNext+max_pin_id
for i in range(1, 1000):
    items = urlrequest(url)
    max_pin_id = downloaditems(items)
    url = urlNext+max_pin_id
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-182-04ec47f131c1> in <module>()
#       2 url = urlNext+max_pin_id
#       3 for i in range(1, 1000):
# ----> 4     items = urlrequest(url)
#       5     max_pin_id = downloaditems(items)
#       6     url = urlNext+max_pin_id
#
# <ipython-input-173-4a4ab6b81b92> in urlrequest(url)
#       1 def urlrequest(url):
#       2     request = urllib.request.Request(url,headers=headers)
# ----> 3     response = urllib.request.urlopen(request)
#       4     html = response.read()
#       5     soup = BeautifulSoup(html, 'html.parser')
#
# /Users/zihaozhang/anaconda/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# ...
