# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %%
n<-500
# generate a sample from the distribution entailed by the SCM
set.seed(1)
C <- rnorm(n)
A <- .8*rnorm(n)
K <- A + 0.1*rnorm(n)
X <- C - 2*A + 0.2*rnorm(n)
F <- 3*X + 0.8*rnorm(n)
D <- -2*X + 0.5*rnorm(n)
G <- D + 0.5*rnorm(n)
Y <- 2*K - D + 0.2*rnorm(n)
H <- 0.5*Y + 0.1*rnorm(n)

lm(Y~X)$coefficient
# Out:
# (Intercept)           X
# -0.03323963  1.30291040

# %%
lm(Y~X+K)$coefficient
# Out:
# (Intercept)           X           K
# -0.02342617  2.01335136  1.99520944

# %%
lm(X~Y+K)$coefficient
# Out:
# (Intercept)           Y           K
#  0.01183179  0.46653730 -1.05431067

# %%
lm(Y~X+F+C+K)$coefficient
# Out:
# (Intercept)           X           F           C           K
# -0.02406900  1.98769241 -0.02641737  0.11526356  1.78759472

# %% [markdown]
# Include all the parent in the causal plot, given valid adjuestment thoery, we have unbiased estimator. And its not that the more you include the better. You can see from the SCM plot, that if you include  or H, you are messing up the path from X to Y.
#
# Valid adjustment set are:
#
# Z = {C,A}
# Z = {K}
# Z = {F, C K}

# %%
lm(Y~X+F+C+K + G)$coefficient
# Out:
#  (Intercept)            X            F            C            K            G
#  0.004790955  1.096424805 -0.023595559  0.018866597  1.986380213 -0.483464729

# %%
X <- rnorm(n)
Y <- 5*X

# %%
lm(Y~X)$coefficient
# Out:
#   (Intercept)             X
# -7.944109e-17  5.000000e+00

# %%
lm(X~Y)$coefficient
# Out:
# (Intercept)           Y
#         0.0         0.2

# %% [markdown]
# Just a brief note on why you see the slope smaller for one regression. Both slopes depend on three numbers: standard deviations of x and y (sx and sy), and correlation between x and y (r). The regression with y as response has slope rsysx and the regression with x as response has slope rsxsy, hence the ratio of the first slope to the reciprocal of the second is equal to r2≤1.
#
# So the greater the proportion of variance explained, the closer the slopes obtained from each case. Note that the proportion of variance explained is symmetric and equal to the squared correlation in simple linear regression.

# %% [markdown]
# It is not like the smoking causing lung cancer.

# %% [markdown]
# ## randomized trial
# if treatment is completely randomized, the valid adjustment set is empty

# %% [markdown]
# ## Instrumental variables

# %%
library(AER)
library(lmtest)
data("CollegeDistance")

# %%
cd.d<-CollegeDistance
M <- cor(cd.d[,c("wage","distance","education")])
M
# Out:
#           wage          distance      education
# wage       1.0000000000 -0.0003904288  0.02385805
# distance  -0.0003904288  1.0000000000 -0.09318309
# education  0.0238580537 -0.0931830901  1.00000000

# %%
simple.ed.1s<- lm(education ~ distance,data=cd.d)
cd.d$ed.pred<- predict(simple.ed.1s)
simple.ed.2s<- lm(wage ~ urban + gender + ethnicity + unemp + ed.pred , data=cd.d)

library(arm)
coefplot(lm(wage ~ urban + gender + ethnicity + unemp + education,data=cd.d),vertical=FALSE,var.las=1,varnames=c("Education","Unemp","Hispanic","Af-am","Female","Urban","Education"))
coefplot(simple.ed.2s , vertical=FALSE,var.las=1,varnames=c("Education","Unemp","Hispanic","Af-am","Female","Urban","Education"),main = "Instrumental estimation")
# Out:
# Plot with title "Regression Estimates"
# Plot with title "Instrumental estimation"

# %%
simple.comp<- encomptest(wage ~ urban + gender + ethnicity + unemp + ed.pred , wage ~ urban + gender + ethnicity + unemp + education , data=cd.d)
ftest.1s<- encomptest(education ~ tuition + gender + ethnicity + urban , education ~ distance , data=cd.d)

simple.comp
ftest.1s
# Out:
#           Res.Df Df F           Pr(>F)
# M1 vs. ME 4731   -1  0.01962008 8.886093e-01
# M2 vs. ME 4731   -1 41.12240649 1.569438e-10
#           Res.Df Df F        Pr(>F)
# M1 vs. ME 4732   -1 48.27910 4.198757e-12
# M2 vs. ME 4732   -5 13.93348 1.516838e-13

# %%
## 2SLS in R ##

library(foreign)

AllData <- read.dta("newdail2002v2.dta",  convert.factors=FALSE)
CampaignData <- na.omit(subset(AllData, select=c(votes1st,incumb,spend_regular,spend_regularXinc,spend_public,partyquota1997,electoraK,dublin,senator,councillor,wonseat)))

## OLS ##

olsmodel <- lm(votes1st ~ incumb + spend_regular + spend_regularXinc, data=CampaignData)
summary(olsmodel)

olsmodel2 <- lm(votes1st ~ incumb + spend_regular + spend_regularXinc + spend_public, data=CampaignData)
summary(olsmodel2)
# Out:
# Call:
# lm(formula = votes1st ~ incumb + spend_regular + spend_regularXinc,
#     data = CampaignData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5560.1  -936.4  -276.2   907.0  7286.3
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        512.47004  167.88884   3.052  0.00241 **
# incumb            4892.99700  577.91559   8.467 3.68e-16 ***
# spend_regular        0.20209    0.01222  16.543  < 2e-16 ***
# spend_regularXinc   -0.09768    0.03509  -2.784  0.00560 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1839 on 446 degrees of freedom
# Multiple R-squared:  0.653,	Adjusted R-squared:  0.6507
# F-statistic: 279.8 on 3 and 446 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = votes1st ~ incumb + spend_regular + spend_regularXinc +
#     spend_public, data = CampaignData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5507.5  -929.8  -240.7   918.7  7120.7
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        503.80278  164.90496   3.055  0.00238 **
# incumb            4369.68200  581.32963   7.517 3.12e-13 ***
# spend_regular        0.20066    0.01200  16.717  < 2e-16 ***
# spend_regularXinc   -0.09838    0.03447  -2.854  0.00451 **
# spend_public         0.09990    0.02398   4.167 3.72e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1806 on 445 degrees of freedom
# Multiple R-squared:  0.6661,	Adjusted R-squared:  0.6631
# F-statistic: 221.9 on 4 and 445 DF,  p-value: < 2.2e-16

# %%
## 2SLS by hand -- this replicates models 1 and 2, Table 3 in Benoit and Laver 2008

first.stage.1 <- lm(spend_regular ~ partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
summary(first.stage.1)

CampaignData$instrumented.spending <- first.stage.1$fitted.values
CampaignData$inst.spend.inc <- CampaignData$instrumented.spending * CampaignData$incumb

second.stage.1 <- lm(votes1st ~ incumb + instrumented.spending + inst.spend.inc, data=CampaignData)
summary(second.stage.1)


first.stage.2 <- lm(spend_public ~ partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
summary(first.stage.2)

CampaignData$instrumented.pspending <- first.stage.2$fitted.values

second.stage.2 <- lm(votes1st ~ incumb + instrumented.spending + inst.spend.inc + instrumented.pspending, data=CampaignData)
summary(second.stage.2)
# Out:
# Call:
# lm(formula = spend_regular ~ partyquota1997 + electoraK + dublin +
#     senator + councillor, data = CampaignData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -14321.4  -5126.7   -811.8   3903.4  26829.7
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     6194.87    1650.77   3.753 0.000198 ***
# partyquota1997  4321.96     363.54  11.889  < 2e-16 ***
# electoraK         22.43      21.18   1.059 0.290142
# dublin           523.09     782.89   0.668 0.504387
# senator          553.94    2620.67   0.211 0.832692
# councillor      5944.19    1181.94   5.029 7.16e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6837 on 444 degrees of freedom
# Multiple R-squared:  0.2742,	Adjusted R-squared:  0.266
# F-statistic: 33.54 on 5 and 444 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = votes1st ~ incumb + instrumented.spending + inst.spend.inc,
#     data = CampaignData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4940.0 -1386.3  -397.4  1012.5  8161.9
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)           -1.352e+03  3.404e+02  -3.971 8.33e-05 ***
# incumb                 4.806e+03  9.681e+02   4.964 9.83e-07 ***
# instrumented.spending  3.658e-01  2.908e-02  12.576  < 2e-16 ***
# inst.spend.inc        -1.313e-01  6.437e-02  -2.039    0.042 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1994 on 446 degrees of freedom
# Multiple R-squared:  0.5922,	Adjusted R-squared:  0.5894
# F-statistic: 215.9 on 3 and 446 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = spend_public ~ partyquota1997 + electoraK + dublin +
#     senator + councillor, data = CampaignData)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#  -5857  -1462   -372    347  37968
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     1818.57     946.51   1.921   0.0553 .
# partyquota1997  2118.18     208.44  10.162   <2e-16 ***
# electoraK        -24.40      12.14  -2.010   0.0451 *
# dublin           228.37     448.89   0.509   0.6112
# senator         1433.13    1502.63   0.954   0.3407
# councillor     -1074.67     677.70  -1.586   0.1135
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3920 on 444 degrees of freedom
# Multiple R-squared:  0.2003,	Adjusted R-squared:  0.1913
# F-statistic: 22.25 on 5 and 444 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = votes1st ~ incumb + instrumented.spending + inst.spend.inc +
#     instrumented.pspending, data = CampaignData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4876.2 -1326.9  -377.4   975.9  8229.3
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -860.43212  392.20033  -2.194   0.0288 *
# incumb                 4690.26406  963.66448   4.867 1.58e-06 ***
# instrumented.spending     0.29836    0.03968   7.519 3.07e-13 ***
# inst.spend.inc           -0.14161    0.06414  -2.208   0.0278 *
# instrumented.pspending    0.22312    0.08992   2.481   0.0135 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1982 on 445 degrees of freedom
# Multiple R-squared:  0.5977,	Adjusted R-squared:  0.5941
# F-statistic: 165.3 on 4 and 445 DF,  p-value: < 2.2e-16

# %%
## Issue to consider -- is interaction also endogenous?
## 在经济学里, endogenous 指的是各种因素或者变量是内在的, 可以控制的, 比如国内的物价,国家可以干预. 相反的exogenous, 指的是不可控的外在因素
## Example of difference in standard errors

second.stage.1v2 <- lm(votes1st ~ instrumented.spending, data=CampaignData)
summary(second.stage.1v2)

## 2SLS ##
## compare standard errors 

#install.packages("AER")
library(AER)

tslsmodel <- ivreg(votes1st  ~ spend_regular | partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
summary(tslsmodel)
# Out:
# Call:
# lm(formula = votes1st ~ instrumented.spending, data = CampaignData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6793.1 -1572.2  -362.2  1171.7  7888.6
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)           -2.135e+03  3.428e+02  -6.229 1.08e-09 ***
# instrumented.spending  4.986e-01  2.613e-02  19.078  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2314 on 448 degrees of freedom
# Multiple R-squared:  0.4483,	Adjusted R-squared:  0.447
# F-statistic:   364 on 1 and 448 DF,  p-value: < 2.2e-16
# Call:
# ivreg(formula = votes1st ~ spend_regular | partyquota1997 + electoraK +
#     dublin + senator + councillor, data = CampaignData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -13143.1  -1787.0    505.9   2109.1   7572.2
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -2.135e+03  4.575e+02  -4.668 4.03e-06 ***
# spend_regular  4.986e-01  3.487e-02  14.296  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3088 on 448 degrees of freedom
# Multiple R-Squared: 0.01735,	Adjusted R-squared: 0.01516
# Wald test: 204.4 on 1 and 448 DF,  p-value: < 2.2e-16

# %%
## Complete models with 2SLS
## note incumbency is also an instrument

tslsmodel.1 <- ivreg(votes1st  ~ incumb + spend_regular + spend_regularXinc | incumb + partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
summary(tslsmodel.1)

tslsmodel.2 <- ivreg(votes1st  ~ incumb + spend_regular + spend_regularXinc + spend_public | incumb + partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
summary(tslsmodel.2)


## An alternate package 

#install.packages("sem")
library(sem)

tslsmodel.3 <- tsls(votes1st  ~ incumb + spend_regular + spend_regularXinc, ~ incumb + partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
summary(tslsmodel.3)

tslsmodel.4 <- tsls(votes1st  ~ incumb + spend_regular + spend_regularXinc + spend_public , ~ incumb + partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
summary(tslsmodel.4)


## 2 stage estimator with a binary dv

probit.model <- glm(wonseat ~ incumb + spend_regular + spend_regularXinc + spend_public, family=binomial(link=probit), data=CampaignData)
summary(probit.model)


## (sort of) replication of table 5

tspmodel.1 <- glm(wonseat ~ incumb + instrumented.spending + inst.spend.inc + instrumented.pspending, family=binomial(link=probit), data=CampaignData)
summary(tspmodel.1)

## 2SCML

reg.inst1 <- lm(spend_regular ~ incumb + partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
reg.inst2 <- lm(spend_regularXinc ~ incumb + partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)
reg.inst3 <- lm(spend_public ~ incumb + partyquota1997 + electoraK + dublin + senator + councillor, data=CampaignData)

CampaignData$inst1 <- reg.inst1$residuals
CampaignData$inst2 <- reg.inst2$residuals
CampaignData$inst3 <- reg.inst3$residuals

tscml.model <- glm(wonseat ~ incumb + spend_regular + spend_regularXinc + spend_public + inst1 + inst2 + inst3, family=binomial(link=probit), data=CampaignData)
summary(tscml.model)

## test for endogeneity

#install.packages("lmtest")
library(lmtest)

lrtest(probit.model, tscml.model)
# Out:
# Call:
# lm(formula = votes1st ~ instrumented.spending, data = CampaignData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6793.1 -1572.2  -362.2  1171.7  7888.6
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)           -2.135e+03  3.428e+02  -6.229 1.08e-09 ***
# instrumented.spending  4.986e-01  2.613e-02  19.078  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2314 on 448 degrees of freedom
# Multiple R-squared:  0.4483,	Adjusted R-squared:  0.447
# F-statistic:   364 on 1 and 448 DF,  p-value: < 2.2e-16
# Call:
# ivreg(formula = votes1st ~ spend_regular | partyquota1997 + electoraK +
#     dublin + senator + councillor, data = CampaignData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -13143.1  -1787.0    505.9   2109.1   7572.2
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -2.135e+03  4.575e+02  -4.668 4.03e-06 ***
# spend_regular  4.986e-01  3.487e-02  14.296  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3088 on 448 degrees of freedom
# Multiple R-Squared: 0.01735,	Adjusted R-squared: 0.01516
# Wald test: 204.4 on 1 and 448 DF,  p-value: < 2.2e-16
# Call:
# ivreg(formula = votes1st ~ incumb + spend_regular + spend_regularXinc |
#     incumb + partyquota1997 + electoraK + dublin + senator +
#         councillor, data = CampaignData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9559.5 -1397.7   279.3  1330.0  9609.0
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -1.130e+03  4.309e+02  -2.623 0.009022 **
# incumb             1.652e+04  4.477e+03   3.690 0.000252 ***
# spend_regular      3.549e-01  3.747e-02   9.472  < 2e-16 ***
# spend_regularXinc -8.692e-01  2.764e-01  -3.144 0.001775 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2693 on 446 degrees of freedom
# Multiple R-Squared: 0.2561,	Adjusted R-squared: 0.2511
# Wald test:   120 on 3 and 446 DF,  p-value: < 2.2e-16
# Call:
# ivreg(formula = votes1st ~ incumb + spend_regular + spend_regularXinc +
#     spend_public | incumb + partyquota1997 + electoraK + dublin +
#     senator + councillor, data = CampaignData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9019.6 -1318.1   258.9  1298.3  9291.8
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -1.054e+03  4.787e+02  -2.202  0.02821 *
# incumb             1.557e+04  5.233e+03   2.975  0.00309 **
# spend_regular      3.459e-01  4.563e-02   7.580 2.02e-13 ***
# spend_regularXinc -8.358e-01  2.869e-01  -2.913  0.00376 **
# spend_public       8.456e-02  2.605e-01   0.325  0.74567
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2608 on 445 degrees of freedom
# Multiple R-Squared: 0.3038,	Adjusted R-squared: 0.2975
# Wald test: 95.94 on 4 and 445 DF,  p-value: < 2.2e-16
#  2SLS Estimates
#
# Model Formula: votes1st ~ incumb + spend_regular + spend_regularXinc
#
# Instruments: ~incumb + partyquota1997 + electoraK + dublin + senator + councillor
#
# Residuals:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -9559.5 -1397.7   279.3     0.0  1330.0  9609.0
#
#                        Estimate    Std. Error  t value   Pr(>|t|)
# (Intercept)       -1.130069e+03  4.308783e+02 -2.62271 0.00902202 **
# incumb             1.652000e+04  4.477081e+03  3.68990 0.00025206 ***
# spend_regular      3.549001e-01  3.746679e-02  9.47239 < 2.22e-16 ***
# spend_regularXinc -8.692365e-01  2.764310e-01 -3.14450 0.00177488 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2692.5499617 on 446 degrees of freedom
#  2SLS Estimates
#
# Model Formula: votes1st ~ incumb + spend_regular + spend_regularXinc + spend_public
#
# Instruments: ~incumb + partyquota1997 + electoraK + dublin + senator + councillor
#
# Residuals:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -9019.6 -1318.1   258.9     0.0  1298.3  9291.8
#
#                        Estimate    Std. Error  t value  Pr(>|t|)
# (Intercept)       -1.053939e+03  4.787161e+02 -2.20160 0.0282064 *
# incumb             1.556926e+04  5.232868e+03  2.97528 0.0030866 **
# spend_regular      3.459188e-01  4.563460e-02  7.58019 2.025e-13 ***
# spend_regularXinc -8.357638e-01  2.869047e-01 -2.91304 0.0037595 **
# spend_public       8.455777e-02  2.605312e-01  0.32456 0.7456673
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2607.7729721 on 445 degrees of freedom
# Call:
# glm(formula = wonseat ~ incumb + spend_regular + spend_regularXinc +
#     spend_public, family = binomial(link = probit), data = CampaignData)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2825  -0.5383  -0.1967   0.7043   2.5682
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)       -2.273e+00  2.211e-01 -10.279  < 2e-16 ***
# incumb             2.018e+00  5.070e-01   3.981 6.86e-05 ***
# spend_regular      9.218e-05  1.271e-05   7.252 4.10e-13 ***
# spend_regularXinc -5.321e-05  2.969e-05  -1.792   0.0731 .
# spend_public       9.205e-05  3.751e-05   2.454   0.0141 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 588.08  on 449  degrees of freedom
# Residual deviance: 347.53  on 445  degrees of freedom
# AIC: 357.53
#
# Number of Fisher Scoring iterations: 6
# Call:
# glm(formula = wonseat ~ incumb + instrumented.spending + inst.spend.inc +
#     instrumented.pspending, family = binomial(link = probit),
#     data = CampaignData)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.8326  -0.5004  -0.3629   0.6928   2.3536
#
# Coefficients:
#                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)            -2.365e+00  3.129e-01  -7.559 4.05e-14 ***
# incumb                  2.991e+00  6.926e-01   4.319 1.57e-05 ***
# instrumented.spending   1.064e-04  2.882e-05   3.693 0.000221 ***
# inst.spend.inc         -1.176e-04  4.577e-05  -2.570 0.010165 *
# instrumented.pspending  8.675e-05  6.327e-05   1.371 0.170369
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 588.08  on 449  degrees of freedom
# Residual deviance: 386.57  on 445  degrees of freedom
# AIC: 396.57
#
# Number of Fisher Scoring iterations: 5
# Call:
# glm(formula = wonseat ~ incumb + spend_regular + spend_regularXinc +
#     spend_public + inst1 + inst2 + inst3, family = binomial(link = probit),
#     data = CampaignData)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.3234  -0.5288  -0.1563   0.6420   2.8814
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)       -2.787e+00  3.480e-01  -8.008 1.17e-15 ***
# incumb             5.176e+00  3.164e+00   1.636   0.1019
# spend_regular      1.309e-04  2.698e-05   4.851 1.23e-06 ***
# spend_regularXinc -2.894e-04  1.810e-04  -1.599   0.1098
# spend_public       1.839e-04  1.316e-04   1.397   0.1623
# inst1             -4.690e-05  2.680e-05  -1.750   0.0801 .
# inst2              2.557e-04  1.825e-04   1.401   0.1612
# inst3             -1.152e-04  1.356e-04  -0.850   0.3953
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 588.08  on 449  degrees of freedom
# Residual deviance: 337.74  on 442  degrees of freedom
# AIC: 353.74
#
# Number of Fisher Scoring iterations: 6
#   #Df LogLik    Df Chisq    Pr(>Chisq)
# 1 5   -173.7628 NA       NA         NA
# 2 8   -168.8721  3 9.781433 0.02051839
